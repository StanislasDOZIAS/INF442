# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("matrix.csv", header=None)

# %%
sns.heatmap(data)
# Out:
# <AxesSubplot:>

# %%
data = pd.read_csv("matrix_diag.csv", header=None)

# %%
sns.heatmap(data)
# Out:
# <AxesSubplot:>

# %%
a = 0.423
